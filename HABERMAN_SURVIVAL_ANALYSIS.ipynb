# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
haberman = pd.read_csv("C:/Users/SAHIL/Downloads/haberman.csv")
haberman
# Out:
#      age  year  nodes  status
# 0     30    64      1       1
# 1     30    62      3       1
# 2     30    65      0       1
# 3     31    59      2       1
# 4     31    65      4       1
# ..   ...   ...    ...     ...
# 301   75    62      1       1
# 302   76    67      0       1
# 303   77    65      3       1
# 304   78    65      1       2
# 305   83    58      2       2
#
# [306 rows x 4 columns]

# %%
haberman.shape
# Out:
# (306, 4)

# %%
haberman.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
haberman.columns=['Age','Operation_Year','positive_lymph','Survival_Status']
print(haberman.columns)
haberman.head()
# Out:
# Index(['Age', 'Operation_Year', 'positive_lymph', 'Survival_Status'], dtype='object')
#    Age  Operation_Year  positive_lymph  Survival_Status
# 0   30              64               1                1
# 1   30              62               3                1
# 2   30              65               0                1
# 3   31              59               2                1
# 4   31              65               4                1

# %%
haberman.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              306 non-null    int64
#  1   Operation_Year   306 non-null    int64
#  2   positive_lymph   306 non-null    int64
#  3   Survival_Status  306 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
haberman['Survival_Status'].value_counts()
# Out:
# 1    225
# 2     81
# Name: Survival_Status, dtype: int64

# %%
haberman.describe()
# Out:
#               Age  Operation_Year  positive_lymph  Survival_Status
# count  306.000000      306.000000      306.000000       306.000000
# mean    52.457516       62.852941        4.026144         1.264706
# std     10.803452        3.249405        7.189654         0.441899
# min     30.000000       58.000000        0.000000         1.000000
# 25%     44.000000       60.000000        0.000000         1.000000
# 50%     52.000000       63.000000        1.000000         1.000000
# 75%     60.750000       65.750000        4.000000         2.000000
# max     83.000000       69.000000       52.000000         2.000000

# %%
haberman.plot(kind='scatter',x='Age',y='positive_lymph')
plt.show()

# %%
sns.set_style('whitegrid')
0g= sns.FacetGrid(haberman,hue='Survival_Status',height=6)
g.map(plt.scatter,'Age','positive_lymph')
g.add_legend()
plt.show()

# %%
plt.close()
sns.set_style('whitegrid')
sns.pairplot(haberman,hue='Survival_Status',vars=['Age','Operation_Year','positive_lymph'],height=3)
plt.show()

# %%
g= sns.FacetGrid(haberman,hue='Survival_Status',height=3)
g.map(sns.distplot,'positive_lymph')
g.add_legend()
plt.show()
# Out:
# C:\Users\SAHIL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\SAHIL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
g= sns.FacetGrid(haberman,hue='Survival_Status',height=3)
g.map(sns.distplot,'Age')
g.add_legend()
plt.show()
# Out:
# C:\Users\SAHIL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\SAHIL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
g= sns.FacetGrid(haberman,hue='Survival_Status',height=3)
g.map(sns.distplot,'Operation_Year')
g.add_legend()
plt.show()
# Out:
# C:\Users\SAHIL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\SAHIL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
alive=haberman.loc[haberman["Survival_Status"]==1]
dead=haberman.loc[haberman["Survival_Status"]==2]

# %%
counts, bin_edges = np.histogram(alive['positive_lymph'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)
plt.legend(['Pdf for the patients who survive more than 5 years',
            'Cdf for the patients who survive more than 5 years'])
plt.show()
# Out:
# [0.83555556 0.08       0.02222222 0.02666667 0.01777778 0.00444444
#  0.00888889 0.         0.         0.00444444]
# [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]

# %%
counts, bin_edges = np.histogram(dead['positive_lymph'], bins=10, density=True)

pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)
plt.legend(['Pdf for the patients who dead Within 5 years',
            'Cdf for the patients who dead within 5 years'])
plt.show()
# Out:
# [0.56790123 0.14814815 0.13580247 0.04938272 0.07407407 0.
#  0.01234568 0.         0.         0.01234568]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]

# %%
print("Summary statistics for the people alive for more than 5 years")
alive.describe()
# Out:
# Summary statistics for the people alive for more than 5 years
#               Age  Operation_Year  positive_lymph  Survival_Status
# count  225.000000      225.000000      225.000000            225.0
# mean    52.017778       62.862222        2.791111              1.0
# std     11.012154        3.222915        5.870318              0.0
# min     30.000000       58.000000        0.000000              1.0
# 25%     43.000000       60.000000        0.000000              1.0
# 50%     52.000000       63.000000        0.000000              1.0
# 75%     60.000000       66.000000        3.000000              1.0
# max     77.000000       69.000000       46.000000              1.0

# %%
print("Summary statistics for the people dead for more than 5 years")
dead.describe()
# Out:
# Summary statistics for the people dead for more than 5 years
#              Age  Operation_Year  positive_lymph  Survival_Status
# count  81.000000       81.000000       81.000000             81.0
# mean   53.679012       62.827160        7.456790              2.0
# std    10.167137        3.342118        9.185654              0.0
# min    34.000000       58.000000        0.000000              2.0
# 25%    46.000000       59.000000        1.000000              2.0
# 50%    53.000000       63.000000        4.000000              2.0
# 75%    61.000000       65.000000       11.000000              2.0
# max    83.000000       69.000000       52.000000              2.0

# %%
print("median")
print(np.median(alive['positive_lymph']))
print(np.median(np.append(alive['positive_lymph'],50)))
print(np.median(dead['positive_lymph']))

print("Quantiles")
print(np.percentile(alive['positive_lymph'],np.arange(0,100,25)))
print(np.percentile(dead['positive_lymph'],np.arange(0,100,25)))

print('90th Percentile')
print(np.percentile(alive['positive_lymph'],90))
print(np.percentile(dead['positive_lymph'],90))

from statsmodels import robust
print("Median Absolute Deviations")
print(robust.mad(alive["positive_lymph"]))
print(robust.mad(dead["positive_lymph"]))
# Out:
# median
# 0.0
# 0.0
# 4.0
# Quantiles
# [0. 0. 0. 3.]
# [ 0.  1.  4. 11.]
# 90th Percentile
# 8.0
# 20.0
# Median Absolute Deviations
# 0.0
# 5.930408874022408

# %%
sns.boxplot(x='Survival_Status',y = 'positive_lymph',data=haberman)
# Out:
# <Axes: xlabel='Survival_Status', ylabel='positive_lymph'>

# %%
sns.violinplot(x='Survival_Status',y = 'positive_lymph',data=haberman)
# Out:
# <Axes: xlabel='Survival_Status', ylabel='positive_lymph'>

# %%
sns.boxplot(x='Survival_Status',y = 'Age',data=haberman)
# Out:
# <Axes: xlabel='Survival_Status', ylabel='Age'>

# %%
sns.boxplot(x='Survival_Status',y = 'Operation_Year',data=haberman)
# Out:
# <Axes: xlabel='Survival_Status', ylabel='Operation_Year'>

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for idx, feature in enumerate(list(haberman.columns)[:-1]):
    sns.violinplot( x='Survival_Status', y=feature, data=haberman, ax=axes[idx])
plt.show()

# %%
sns.jointplot(x="Age", y="Operation_Year", data=haberman, kind="kde")
plt.show()

# %% [markdown]
# # Observation:
#
# The number of positive lymph nodes of the survivors is highly densed from 0 to 5.
# Almost 80% of the patients have less than or equal to 5 positive lymph survived more than 5 years.
# From box plots and violin plots, we can say that more no of patients who are dead have age between 46-62,year between 59-65 and the patients who survived have age between 42-60, year between 60-66.
